# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-SVF9UFS/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
